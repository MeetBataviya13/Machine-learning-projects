# %% [markdown]
# # Notebook 01: Data Exploration
#
# ## Objective
# In this notebook, we:
# - Load raw customer and transaction datasets
# - Understand dataset structure and column types
# - Inspect distributions, ranges, and summary statistics
# - Identify missing values and potential data issues
#
# > Note: No cleaning or feature engineering is performed in this notebook.
#
# ## Problem Context
#
# Before building predictive models, it is essential to understand:
#
# - Data structure
# - Data volume
# - Data quality
# - Behavioral patterns
#
# This step ensures informed decisions during cleaning and feature engineering.

# %% [markdown]
# ### Step 1 : load libraries and datasets

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
