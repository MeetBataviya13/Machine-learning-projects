# %% [markdown]
# # Notebook 05: Model Building
#
# ## Objective
# In this notebook, we:
# - Split the dataset into training and testing sets
# - Train supervised regression models
# - Compare multiple algorithms
# - Generate predictions for customer lifetime value
#
# > Note: No model evaluation beyond basic training metrics is done here.
#
# ## Problem Context
#
# The goal is to build predictive models that learn the relationship between customer behavior and future revenue generation.
