# %% [markdown]
# # Notebook 03: Exploratory Data Analysis (EDA)
#
# ## Objective
# In this notebook, we:
# - Analyze spending patterns and purchase behavior
# - Study customer segments
# - Identify trends over time
# - Visualize key variables
# - Explore relationships between customer activity and potential CLV drivers
#
# > Note: No ML modeling is performed here.
#
# ## Problem Context
#
# EDA helps uncover behavioral insights and validate assumptions that guide feature engineering and model selection.
